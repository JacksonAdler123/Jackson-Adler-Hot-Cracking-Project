# %% [markdown]
# <a href="https://colab.research.google.com/github/JacksonAdler123/Jackson-Adler-Hot-Cracking-Project/blob/main/Jackson_Adler_Hot_Cracking_Analysis_(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Attempting a ANN model
# #(How much better of a fit can I obtain compared to MLR)

# %%
import numpy as np
import pandas as pd
import math

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import datasets
from sklearn import metrics
from sklearn.feature_selection import SelectFromModel
import matplotlib as mp
from keras.layers import Dense
from keras.models import Sequential, load_model
from google.colab import drive
drive.mount('/content/drive')
# %matplotlib inline
# !conda info
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /bin/bash: line 1: conda: command not found

# %% [markdown]
# #Steel Dataset: ANN predicting Strain

# %%
data = pd.read_csv("/content/drive/MyDrive/steel_data.csv", sep = ",")
print(data.head())
display(data)
# Out:
#    No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...    Al  \
# 0    1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...  0.02
# 1    2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...  0.02
# 2    3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...  0.02
# 3    4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...  0.02
# 4    5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...  0.02
#
#     Ti    V    B    Th    I     U    Ve  Strain  TCL
# 0  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.5
# 1  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.1
# 2  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.9
# 3  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.7
# 4  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.5
#
# [5 rows x 23 columns]
#      No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...  \
# 0      1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...
# 1      2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...
# 2      3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...
# 3      4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...
# 4      5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...
# ..   ...    ...   ...   ...    ...    ...    ...    ...   ...    ...  ...
# 482  483  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  ...
# 483  484  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  ...
# 484  485  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  ...
# 485  486  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  ...
# 486  487  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 23 columns]

# %%
subdata = data[np.isfinite(data['Strain'])]
display(subdata)
# Out:
#      No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...  \
# 0      1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...
# 1      2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...
# 2      3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...
# 3      4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...
# 4      5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...
# ..   ...    ...   ...   ...    ...    ...    ...    ...   ...    ...  ...
# 482  483  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  ...
# 483  484  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  ...
# 484  485  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  ...
# 485  486  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  ...
# 486  487  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 23 columns]

# %%
subdata = subdata.loc[:, 'C':'Strain']
display(subdata)
# Out:
#          C    Si    Mn      P      S     Cr     Ni    Mo      N    Nb  ...  \
# 0    0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  0.00  ...
# 1    0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  0.00  ...
# 2    0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  0.00  ...
# 3    0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  0.00  ...
# 4    0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  0.00  ...
# ..     ...   ...   ...    ...    ...    ...    ...   ...    ...   ...  ...
# 482  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  0.28  ...
# 483  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  0.28  ...
# 484  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  0.30  ...
# 485  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  0.00  ...
# 486  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  0.00  ...
#
#       Cu    Al   Ti    V    B    Th    I     U    Ve  Strain
# 0    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# 1    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# 2    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# 3    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# 4    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# ..   ...   ...  ...  ...  ...   ...  ...   ...   ...     ...
# 482  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
# 483  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
# 484  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
# 485  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
# 486  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
#
# [487 rows x 21 columns]

# %%
subdata.drop("Th", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
subdata.drop("Ve", axis=1, inplace=True)
display(subdata)
# Out:
#          C    Si    Mn      P      S     Cr     Ni    Mo      N    Nb    Co  \
# 0    0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  0.00  0.00
# 1    0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  0.00  0.00
# 2    0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  0.00  0.00
# 3    0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  0.00  0.00
# 4    0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  0.00  0.15
# ..     ...   ...   ...    ...    ...    ...    ...   ...    ...   ...   ...
# 482  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  0.28  0.00
# 483  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  0.28  0.00
# 484  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  0.30  0.00
# 485  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  0.00  0.00
# 486  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  0.00  0.00
#
#       Cu    Al   Ti    V    B  Strain
# 0    0.0  0.02  0.0  0.0  0.0     4.0
# 1    0.0  0.02  0.0  0.0  0.0     4.0
# 2    0.0  0.02  0.0  0.0  0.0     4.0
# 3    0.0  0.02  0.0  0.0  0.0     4.0
# 4    0.0  0.02  0.0  0.0  0.0     4.0
# ..   ...   ...  ...  ...  ...     ...
# 482  0.0  0.02  0.0  0.0  0.0     1.2
# 483  0.0  0.02  0.0  0.0  0.0     1.2
# 484  0.0  0.02  0.0  0.0  0.0     1.2
# 485  0.0  0.02  0.0  0.0  0.0     1.2
# 486  0.0  0.02  0.0  0.0  0.0     1.2
#
# [487 rows x 17 columns]

# %%
X = subdata.iloc[:, 0:16].values
y = subdata.iloc[:, 16].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

# spliting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from tensorflow.keras.models import Sequential
model = Sequential()

from tensorflow.keras.layers import Dense
model.add(Dense(20, input_dim=n_features, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='linear'))

# %%
def rmse(x,y): return math.sqrt(((x-y)**2).mean())

def mean_absolute_error(x,y): return math.sqrt((abs(x-y)).mean())

def print_score(m):
    res = [rmse(m.predict(X_train), y_train), rmse(m.predict(X_test), y_test),
                m.score(X_train, y_train), m.score(X_test, y_test)]
    if hasattr(m, 'oob_score_'): res.append(m.oob_score_)
    print(res)

# %%
from sklearn.metrics import r2_score
model.compile(loss='mse', optimizer='adam')

# %%
m1 = model.fit(X_train, y_train, epochs=600, batch_size=16, validation_data= (X_test, y_test), verbose=0)

# %%
#Analyzing Sucsess of the ANN
yhat = model.predict(X_test)
error = mean_absolute_error(y_test, yhat)
sizeXtest = np.size(X_test)
sizeXtrain = np.size(X_train)
sizeytrain = np.size(y_train)
sizeytest = np.size(y_test)
size_yhat = np.size(yhat)
print('sizes of sizeXtrain, X_test, y_test, yhat ',sizeXtrain, sizeXtest, sizeytrain, sizeytest, size_yhat)
print('X_test.shape ... ', X_test.shape)
print('MAE: %.3f' % error)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# sizes of sizeXtrain, X_test, y_test, yhat  6224 1568 389 98 98
# X_test.shape ...  (98, 16)
# MAE: 1.151

# %%
#Checking R^2 of model
from sklearn.metrics import r2_score
r2_score(y_test,yhat)
# Out:
# 0.08186816249666395

# %%
rmse(yhat,y_test)
# Out:
# 1.6154299480299943

# %%
# Generating plot comparing predicted values to test values
from matplotlib import pyplot as plt
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter( y_test, yhat, color='black')
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [1,6]
yy = [1, 6]
plt.plot( xx, yy, color="red")
#plt.set_xlabel= 'y_test'
#plt.set_ylabel= 'yhat'
plt.tight_layout()
plt.savefig('Plot-compare-data-vs-fitted.png', dpi=600)

# %%
from matplotlib import pyplot as plt
plt.plot(m1.history['loss'])
plt.plot(m1.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
rmse(yhat,y_test)
# Out:
# 1.6154299480299943

# %% [markdown]
# #Pretty unsucsessful fit. Next I try to predict the total crack length (TCL) for the steel dataset

# %%
#TCL CNN
subdata = data[np.isfinite(data['Strain'])]
display(subdata)
# Out:
#      No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...  \
# 0      1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...
# 1      2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...
# 2      3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...
# 3      4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...
# 4      5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...
# ..   ...    ...   ...   ...    ...    ...    ...    ...   ...    ...  ...
# 482  483  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  ...
# 483  484  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  ...
# 484  485  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  ...
# 485  486  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  ...
# 486  487  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 23 columns]

# %%
subdata = data[np.isfinite(data['TCL'])]
display(subdata)
# Out:
#      No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...  \
# 0      1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...
# 1      2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...
# 2      3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...
# 3      4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...
# 4      5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...
# ..   ...    ...   ...   ...    ...    ...    ...    ...   ...    ...  ...
# 482  483  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  ...
# 483  484  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  ...
# 484  485  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  ...
# 485  486  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  ...
# 486  487  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 23 columns]

# %%
subdata = subdata.loc[:, 'C':'TCL']
display(subdata)
# Out:
#          C    Si    Mn      P      S     Cr     Ni    Mo      N    Nb  ...  \
# 0    0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  0.00  ...
# 1    0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  0.00  ...
# 2    0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  0.00  ...
# 3    0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  0.00  ...
# 4    0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  0.00  ...
# ..     ...   ...   ...    ...    ...    ...    ...   ...    ...   ...  ...
# 482  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  0.28  ...
# 483  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  0.28  ...
# 484  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  0.30  ...
# 485  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  0.00  ...
# 486  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  0.00  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 22 columns]

# %%
subdata.drop("Th", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
#subdata.drop("C", axis=1, inplace=True)
#subdata.drop("Si", axis=1, inplace=True)
#subdata.drop("Mn", axis=1, inplace=True)
#subdata.drop("Nb", axis=1, inplace=True)
##subdata.drop("S", axis=1, inplace=True)
#subdata.drop("Cr", axis=1, inplace=True)
#subdata.drop("Ni", axis=1, inplace=True)
#subdata.drop("Mo", axis=1, inplace=True)
#subdata.drop("N", axis=1, inplace=True)
#subdata.drop("Co", axis=1, inplace=True)
#subdata.drop("B", axis=1, inplace=True)
subdata.drop("Ve", axis=1, inplace=True)
subdata.drop("Strain", axis=1, inplace=True)

display(subdata)
# Out:
#          C    Si    Mn      P      S     Cr     Ni    Mo      N    Nb    Co  \
# 0    0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  0.00  0.00
# 1    0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  0.00  0.00
# 2    0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  0.00  0.00
# 3    0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  0.00  0.00
# 4    0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  0.00  0.15
# ..     ...   ...   ...    ...    ...    ...    ...   ...    ...   ...   ...
# 482  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  0.28  0.00
# 483  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  0.28  0.00
# 484  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  0.30  0.00
# 485  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  0.00  0.00
# 486  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  0.00  0.00
#
#       Cu    Al   Ti    V    B   TCL
# 0    0.0  0.02  0.0  0.0  0.0  1.50
# 1    0.0  0.02  0.0  0.0  0.0  1.10
# 2    0.0  0.02  0.0  0.0  0.0  0.90
# 3    0.0  0.02  0.0  0.0  0.0  3.70
# 4    0.0  0.02  0.0  0.0  0.0  1.50
# ..   ...   ...  ...  ...  ...   ...
# 482  0.0  0.02  0.0  0.0  0.0  0.18
# 483  0.0  0.02  0.0  0.0  0.0  0.00
# 484  0.0  0.02  0.0  0.0  0.0  0.24
# 485  0.0  0.02  0.0  0.0  0.0  0.00
# 486  0.0  0.02  0.0  0.0  0.0  1.47
#
# [487 rows x 17 columns]

# %%
X = subdata.iloc[:, 0:15].values
y = subdata.iloc[:, 16].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

# spliting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from tensorflow.keras.models import Sequential
model = Sequential()

from tensorflow.keras.layers import Dense
model.add(Dense(20, input_dim=n_features, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='linear'))

# %%
from sklearn.metrics import r2_score
model.compile(loss='mse', optimizer='adam')

# %%
mTCL = model.fit(X_train, y_train, epochs=600, batch_size=16, validation_data= (X_test, y_test), verbose=0)

# %%
yhat = model.predict(X_test)
error = mean_absolute_error(y_test, yhat)
sizeXtest = np.size(X_test)
sizeXtrain = np.size(X_train)
sizeytrain = np.size(y_train)
sizeytest = np.size(y_test)
size_yhat = np.size(yhat)
print('sizes of sizeXtrain, X_test, y_test, yhat ',sizeXtrain, sizeXtest, sizeytrain, sizeytest, size_yhat)
print('X_test.shape ... ', X_test.shape)
print('MAE: %.3f' % error)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# sizes of sizeXtrain, X_test, y_test, yhat  5835 1470 389 98 98
# X_test.shape ...  (98, 15)
# MAE: 2.041

# %%
# R^2 score
r2_score(y_test,yhat)
# Out:
# 0.25152209695139915

# %%
from matplotlib import pyplot as plt
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter( y_test, yhat, color='black')
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [1,10]
yy = [1, 10]
plt.plot( xx, yy, color="red")
#plt.set_xlabel= 'y_test'
#plt.set_ylabel= 'yhat'
plt.tight_layout()
plt.savefig('Plot-compare-data-vs-fitted.png', dpi=600)

# %% [markdown]
# #Now I try to create an ANN for the aluminum dataset which predicts the mean crack length (MCL)

# %%
#Al
data = pd.read_csv("/content/drive/MyDrive/Al_data.csv", sep = ",")
print(data.head())
display(data)
# Out:
#      Name    Si   Fe    Cu    Mn    Mg    Cr   Zn    Ti   Zr  V    B   Li  \
# 0  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 1  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 2  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 3  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 4  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
#
#       Al   U    I  Q (kJ/cm)  Speed (mm/min)  Strain    MCL
# 0  94.44  25  200       30.0             100   0.142  2.738
# 1  94.44  25  200       30.0             100   0.245  3.600
# 2  94.44  25  200       30.0             100   0.495  4.815
# 3  94.44  25  200       30.0             100   1.000  5.338
# 4  94.44  25  200       30.0             100   1.997  5.492
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = data[np.isfinite(data['MCL'])]
display(subdata)
# Out:
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = subdata.loc[:, 'Si':'MCL']
display(subdata)
# Out:
#        Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li     Al  \
# 0    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 1    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 2    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 3    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 4    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# ..    ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...    ...
# 190  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 191  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 192  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 193  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 194  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
#
#       U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    25  200       30.0             100  0.14200  2.738
# 1    25  200       30.0             100  0.24500  3.600
# 2    25  200       30.0             100  0.49500  4.815
# 3    25  200       30.0             100  1.00000  5.338
# 4    25  200       30.0             100  1.99700  5.492
# ..   ..  ...        ...             ...      ...    ...
# 190  18  230        NaN             100  0.10170  3.205
# 191  18  230        NaN             100  0.09969  2.369
# 192  18  230        NaN             100  2.31700  4.635
# 193  18  230        NaN             100  0.59890  4.550
# 194  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 19 columns]

# %%
subdata.drop("Q (kJ/cm)", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
subdata.drop("Strain", axis=1, inplace=True)
subdata.drop("Speed (mm/min)", axis=1, inplace=True)
display(subdata)
# Out:
#        Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li     Al  \
# 0    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 1    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 2    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 3    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 4    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# ..    ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...    ...
# 190  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 191  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 192  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 193  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 194  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
#
#        MCL
# 0    2.738
# 1    3.600
# 2    4.815
# 3    5.338
# 4    5.492
# ..     ...
# 190  3.205
# 191  2.369
# 192  4.635
# 193  4.550
# 194  4.062
#
# [195 rows x 14 columns]

# %%
X = subdata.iloc[:, 0:13].values
y = subdata.iloc[:, 13].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
from tensorflow.keras.models import Sequential
model = Sequential()

from tensorflow.keras.layers import Dense
model.add(Dense(20, input_dim=n_features, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='linear'))

# %%
from sklearn.metrics import r2_score
model.compile(loss='mse', optimizer='adam')

# %%
m2 = model.fit(X_train, y_train, epochs=600, batch_size=16, validation_data= (X_test, y_test), verbose=0)

# %%
yhat = model.predict(X_test)
error = mean_absolute_error(y_test, yhat)
sizeXtest = np.size(X_test)
sizeXtrain = np.size(X_train)
sizeytrain = np.size(y_train)
sizeytest = np.size(y_test)
size_yhat = np.size(yhat)
print('sizes of sizeXtrain, X_test, y_test, yhat ',sizeXtrain, sizeXtest, sizeytrain, sizeytest, size_yhat)
print('X_test.shape ... ', X_test.shape)
print('MAE: %.3f' % error)
# Out:
# 2/2 [==============================] - 0s 6ms/step
# sizes of sizeXtrain, X_test, y_test, yhat  2028 507 156 39 39
# X_test.shape ...  (39, 13)
# MAE: 1.487

# %%
#Checking R^2 of model
r2_score(y_test,yhat)
# Out:
# 0.6781012574977181

# %%
rmse(yhat,y_test)
# Out:
# 2.9524980194036887

# %%
from matplotlib import pyplot as plt
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter( y_test, yhat, color='black')
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [1,9]
yy = [1, 9]
plt.plot( xx, yy, color="red")
plt.tight_layout()
plt.savefig('Plot-compare-data-vs-fitted.png', dpi=600)

# %%
plt.plot(m2.history['loss'])
plt.plot(m2.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
from keras import backend as K

def coeff_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# #Trying a final ANN using reduced number of alloying percentages. Alloys to used were chosen based on the information gained from the Prinicpal Component Analysis in part 1.

# %%
#Using only the elements deduced from PCA
data = pd.read_csv("/content/drive/MyDrive/Al_data.csv", sep = ",")
print(data.head())
display(data)
# Out:
#      Name    Si   Fe    Cu    Mn    Mg    Cr   Zn    Ti   Zr  V    B   Li  \
# 0  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 1  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 2  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 3  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 4  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
#
#       Al   U    I  Q (kJ/cm)  Speed (mm/min)  Strain    MCL
# 0  94.44  25  200       30.0             100   0.142  2.738
# 1  94.44  25  200       30.0             100   0.245  3.600
# 2  94.44  25  200       30.0             100   0.495  4.815
# 3  94.44  25  200       30.0             100   1.000  5.338
# 4  94.44  25  200       30.0             100   1.997  5.492
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = data[np.isfinite(data['MCL'])]
display(subdata)
# Out:
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = subdata.loc[:, 'Si':'MCL']
display(subdata)
# Out:
#        Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li     Al  \
# 0    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 1    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 2    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 3    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 4    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# ..    ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...    ...
# 190  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 191  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 192  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 193  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 194  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
#
#       U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    25  200       30.0             100  0.14200  2.738
# 1    25  200       30.0             100  0.24500  3.600
# 2    25  200       30.0             100  0.49500  4.815
# 3    25  200       30.0             100  1.00000  5.338
# 4    25  200       30.0             100  1.99700  5.492
# ..   ..  ...        ...             ...      ...    ...
# 190  18  230        NaN             100  0.10170  3.205
# 191  18  230        NaN             100  0.09969  2.369
# 192  18  230        NaN             100  2.31700  4.635
# 193  18  230        NaN             100  0.59890  4.550
# 194  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 19 columns]

# %%
subdata.drop("Q (kJ/cm)", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
subdata.drop("Strain", axis=1, inplace=True)
subdata.drop("Speed (mm/min)", axis=1, inplace=True)
subdata.drop("Si", axis=1, inplace=True)
subdata.drop("Fe", axis=1, inplace=True)
subdata.drop("Mn", axis=1, inplace=True)
subdata.drop("Cr", axis=1, inplace=True)
subdata.drop("Zn", axis=1, inplace=True)
subdata.drop("Ti", axis=1, inplace=True)
subdata.drop("Zr", axis=1, inplace=True)
subdata.drop("V", axis=1, inplace=True)
subdata.drop("B", axis=1, inplace=True)
subdata.drop("Li", axis=1, inplace=True)
display(subdata)
# Out:
#        Cu    Mg     Al    MCL
# 0    0.02  4.39  94.44  2.738
# 1    0.02  4.39  94.44  3.600
# 2    0.02  4.39  94.44  4.815
# 3    0.02  4.39  94.44  5.338
# 4    0.02  4.39  94.44  5.492
# ..    ...   ...    ...    ...
# 190  3.00  0.02  96.70  3.205
# 191  3.00  0.02  96.70  2.369
# 192  4.96  0.04  94.67  4.635
# 193  4.96  0.04  94.67  4.550
# 194  4.96  0.04  94.67  4.062
#
# [195 rows x 4 columns]

# %%
X = subdata.iloc[:, 0:3].values
y = subdata.iloc[:, 3].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
from tensorflow.keras.models import Sequential
model = Sequential()

from tensorflow.keras.layers import Dense
model.add(Dense(20, input_dim=n_features, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='linear'))

# %%
from sklearn.metrics import r2_score
model.compile(loss='mse', optimizer='adam')

# %%
m_MCL2 = model.fit(X_train, y_train, epochs=600, batch_size=16, validation_data= (X_test, y_test), verbose=0)

# %%
yhat = model.predict(X_test)
error = mean_absolute_error(y_test, yhat)
sizeXtest = np.size(X_test)
sizeXtrain = np.size(X_train)
sizeytrain = np.size(y_train)
sizeytest = np.size(y_test)
size_yhat = np.size(yhat)
print('sizes of sizeXtrain, X_test, y_test, yhat ',sizeXtrain, sizeXtest, sizeytrain, sizeytest, size_yhat)
print('X_test.shape ... ', X_test.shape)
print('MAE: %.3f' % error)
# Out:
# 2/2 [==============================] - 0s 5ms/step
# sizes of sizeXtrain, X_test, y_test, yhat  468 117 156 39 39
# X_test.shape ...  (39, 3)
# MAE: 1.429

# %%
#Checking R^2 of model
r2_score(y_test,yhat)
# Out:
# 0.3514584992490217

# %%
rmse(yhat,y_test)
# Out:
# 2.7324039111902745

# %%
from matplotlib import pyplot as plt
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter( y_test, yhat, color='black')
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [1,9]
yy = [1, 9]
plt.plot( xx, yy, color="red")
plt.tight_layout()
plt.savefig('Plot-compare-data-vs-fitted.png', dpi=600)

# %%
plt.plot(m_MCL2.history['loss'])
plt.plot(m_MCL2.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

# %% [markdown]
# # Considering the size of the dataset and the difficulties of the previous regression attempts, I now attempt Random Forest as a method that I believe has the best chance of fitting the data.
#
# #I start with a Random Forest Regression for the Aluminum Data preducting the MCL

# %%
#Random Forst
data = pd.read_csv("/content/drive/MyDrive/Al_data.csv", sep = ",")
print(data.head())
display(data)
import numpy as np
import pandas as pd
import math

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import datasets
from sklearn import metrics
from sklearn.feature_selection import SelectFromModel
# %matplotlib inline
# !conda info
# Out:
#      Name    Si   Fe    Cu    Mn    Mg    Cr   Zn    Ti   Zr  V    B   Li  \
# 0  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 1  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 2  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 3  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 4  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
#
#       Al   U    I  Q (kJ/cm)  Speed (mm/min)  Strain    MCL
# 0  94.44  25  200       30.0             100   0.142  2.738
# 1  94.44  25  200       30.0             100   0.245  3.600
# 2  94.44  25  200       30.0             100   0.495  4.815
# 3  94.44  25  200       30.0             100   1.000  5.338
# 4  94.44  25  200       30.0             100   1.997  5.492
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]
# /bin/bash: line 1: conda: command not found

# %%
#Random Forst
data = pd.read_csv("/content/drive/MyDrive/Al_data.csv", sep = ",")
print(data.head())
display(data)
# Out:
#      Name    Si   Fe    Cu    Mn    Mg    Cr   Zn    Ti   Zr  V    B   Li  \
# 0  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 1  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 2  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 3  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 4  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
#
#       Al   U    I  Q (kJ/cm)  Speed (mm/min)  Strain    MCL
# 0  94.44  25  200       30.0             100   0.142  2.738
# 1  94.44  25  200       30.0             100   0.245  3.600
# 2  94.44  25  200       30.0             100   0.495  4.815
# 3  94.44  25  200       30.0             100   1.000  5.338
# 4  94.44  25  200       30.0             100   1.997  5.492
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = data[np.isfinite(data['MCL'])]
display(subdata)
# Out:
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = subdata.loc[:, 'Si':'MCL']
display(subdata)
# Out:
#        Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li     Al  \
# 0    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 1    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 2    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 3    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 4    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# ..    ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...    ...
# 190  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 191  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 192  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 193  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 194  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
#
#       U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    25  200       30.0             100  0.14200  2.738
# 1    25  200       30.0             100  0.24500  3.600
# 2    25  200       30.0             100  0.49500  4.815
# 3    25  200       30.0             100  1.00000  5.338
# 4    25  200       30.0             100  1.99700  5.492
# ..   ..  ...        ...             ...      ...    ...
# 190  18  230        NaN             100  0.10170  3.205
# 191  18  230        NaN             100  0.09969  2.369
# 192  18  230        NaN             100  2.31700  4.635
# 193  18  230        NaN             100  0.59890  4.550
# 194  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 19 columns]

# %%
subdata.drop("Q (kJ/cm)", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
subdata.drop("Strain", axis=1, inplace=True)
subdata.drop("Speed (mm/min)", axis=1, inplace=True)
display(subdata)
# Out:
#        Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li     Al  \
# 0    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 1    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 2    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 3    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 4    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# ..    ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...    ...
# 190  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 191  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 192  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 193  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 194  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
#
#        MCL
# 0    2.738
# 1    3.600
# 2    4.815
# 3    5.338
# 4    5.492
# ..     ...
# 190  3.205
# 191  2.369
# 192  4.635
# 193  4.550
# 194  4.062
#
# [195 rows x 14 columns]

# %%
X = subdata.iloc[:, 0:12].values
y = subdata.iloc[:, 13].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
mrf = RandomForestRegressor(n_estimators = 100, n_jobs=-1, oob_score = True)
mrf.fit(X_train, y_train)
print_score(mrf)
# Out:
# [0.9007595736212762, 0.9236694943672434, 0.8385722153508594, 0.8477739657064383, 0.7780609549800401]

# %%
from matplotlib import pyplot as plt

yhat = mrf.predict(X_test)
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter(y_test, yhat)
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [1, 9]
yy = [1, 9]
plt.plot( xx, yy, color="red")
plt.tight_layout()

# %%
# %time preds = np.stack([t.predict(X_test) for t in mrf.estimators_])
np.mean(preds[:,0]), np.std(preds[:,0])
# Out:
# CPU times: user 12.3 ms, sys: 0 ns, total: 12.3 ms
# Wall time: 12.9 ms
# (4.035651122391498, 0.3377187156770573)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,yhat)
# Out:
# 0.8477739657064383

# %%
rmse(yhat,y_test)
# Out:
# 0.9236694943672438

# %%
from sklearn.tree import export_graphviz
import IPython, graphviz, re
from IPython.display import display

def draw_tree(t, df, size=10, ratio=0.33, precision=0):
    """ Draws a representation of a random forest in IPython.
    Parameters:
    -----------
    t: The tree you wish to draw
    df: The data used to train the tree. This is used to get the names of the features.
    """
    s=export_graphviz(t, out_file=None, feature_names=df.columns, filled=True,
                      special_characters=True, rotate=True, precision=precision)
    IPython.display.display(graphviz.Source(re.sub('Tree {',
       f'Tree {{ size={size}; ratio={ratio}', s)))

# %%
df_trn = subdata.iloc[:,0:12]
draw_tree(mrf.estimators_[0], df_trn, precision=3)

# %%
def rf_feat_importance(mrf, df):
    return pd.DataFrame({'cols':df.columns, 'imp':mrf.feature_importances_}
                       ).sort_values('imp', ascending=False)
fi = rf_feat_importance(mrf, df_trn); fi[:10]
fi.plot('cols', 'imp', figsize=(10,6), legend=False);
def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)
plot_fi(fi[:30]);

# %% [markdown]
# #Aluminum Data: Simplifying the Random Forest Regression by Removing elemental compositons deemed not as important from plots above.

# %%
#Aluminum Data: Simplfied RF
data = pd.read_csv("/content/drive/MyDrive/Al_data.csv", sep = ",")
print(data.head())
display(data)
# Out:
#      Name    Si   Fe    Cu    Mn    Mg    Cr   Zn    Ti   Zr  V    B   Li  \
# 0  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 1  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 2  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 3  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 4  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
#
#       Al   U    I  Q (kJ/cm)  Speed (mm/min)  Strain    MCL
# 0  94.44  25  200       30.0             100   0.142  2.738
# 1  94.44  25  200       30.0             100   0.245  3.600
# 2  94.44  25  200       30.0             100   0.495  4.815
# 3  94.44  25  200       30.0             100   1.000  5.338
# 4  94.44  25  200       30.0             100   1.997  5.492
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = data[np.isfinite(data['MCL'])]
display(subdata)
# Out:
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = subdata.loc[:, 'Si':'MCL']
display(subdata)
# Out:
#        Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li     Al  \
# 0    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 1    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 2    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 3    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 4    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# ..    ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...    ...
# 190  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 191  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 192  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 193  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 194  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
#
#       U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    25  200       30.0             100  0.14200  2.738
# 1    25  200       30.0             100  0.24500  3.600
# 2    25  200       30.0             100  0.49500  4.815
# 3    25  200       30.0             100  1.00000  5.338
# 4    25  200       30.0             100  1.99700  5.492
# ..   ..  ...        ...             ...      ...    ...
# 190  18  230        NaN             100  0.10170  3.205
# 191  18  230        NaN             100  0.09969  2.369
# 192  18  230        NaN             100  2.31700  4.635
# 193  18  230        NaN             100  0.59890  4.550
# 194  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 19 columns]

# %%
subdata.drop("Q (kJ/cm)", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
#subdata.drop("Strain", axis=1, inplace=True)
subdata.drop("Speed (mm/min)", axis=1, inplace=True)
subdata.drop("Si", axis=1, inplace=True)
#subdata.drop("Mg", axis=1, inplace=True)
subdata.drop("Fe", axis=1, inplace=True)
subdata.drop("Mn", axis=1, inplace=True)
subdata.drop("Cr", axis=1, inplace=True)
subdata.drop("Zn", axis=1, inplace=True)
subdata.drop("Ti", axis=1, inplace=True)
subdata.drop("Zr", axis=1, inplace=True)
subdata.drop("V", axis=1, inplace=True)
subdata.drop("B", axis=1, inplace=True)
subdata.drop("Li", axis=1, inplace=True)
#subdata.drop("Al", axis=1, inplace=True)

display(subdata)
# Out:
#        Cu    Mg     Al   Strain    MCL
# 0    0.02  4.39  94.44  0.14200  2.738
# 1    0.02  4.39  94.44  0.24500  3.600
# 2    0.02  4.39  94.44  0.49500  4.815
# 3    0.02  4.39  94.44  1.00000  5.338
# 4    0.02  4.39  94.44  1.99700  5.492
# ..    ...   ...    ...      ...    ...
# 190  3.00  0.02  96.70  0.10170  3.205
# 191  3.00  0.02  96.70  0.09969  2.369
# 192  4.96  0.04  94.67  2.31700  4.635
# 193  4.96  0.04  94.67  0.59890  4.550
# 194  4.96  0.04  94.67  0.11540  4.062
#
# [195 rows x 5 columns]

# %%
X = subdata.iloc[:, 0:3].values
y = subdata.iloc[:, 4].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %%
mrf_reduced = RandomForestRegressor(n_estimators = 40, n_jobs=-1, oob_score = True)
mrf_reduced.fit(X_train, y_train)
print_score(mrf_reduced)
# Out:
# [0.9139332358237718, 0.8194845287216916, 0.8455196548169329, 0.8339383696210235, 0.7921741778531555]

# %%
from matplotlib import pyplot as plt

yhat = mrf_reduced.predict(X_test)
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter(y_test, yhat)
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [1, 9]
yy = [1, 9]
plt.plot( xx, yy, color="red")
plt.tight_layout()

# %%
from sklearn.metrics import r2_score
r2_score(y_test,yhat)
# Out:
# 0.8339383696210235

# %%
rmse(yhat,y_test)
# Out:
# 0.8194845287216916

# %% [markdown]
# Very small decrease in R^2, sucessful simplifciaiton

# %% [markdown]
# #Aluminum Data: Testing other Regression models

# %%
#Aluminum Strain Random Forest Regression
data = pd.read_csv("/content/drive/MyDrive/Al_data.csv", sep = ",")
print(data.head())
display(data)
# Out:
#      Name    Si   Fe    Cu    Mn    Mg    Cr   Zn    Ti   Zr  V    B   Li  \
# 0  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 1  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 2  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 3  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
# 4  5083_3  0.14  0.2  0.02  0.67  4.39  0.12  0.0  0.02  0.0  0  0.0  0.0
#
#       Al   U    I  Q (kJ/cm)  Speed (mm/min)  Strain    MCL
# 0  94.44  25  200       30.0             100   0.142  2.738
# 1  94.44  25  200       30.0             100   0.245  3.600
# 2  94.44  25  200       30.0             100   0.495  4.815
# 3  94.44  25  200       30.0             100   1.000  5.338
# 4  94.44  25  200       30.0             100   1.997  5.492
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = data[np.isfinite(data['Strain'])]
display(subdata)
# Out:
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = subdata.loc[:, 'Si':'Strain']
display(subdata)
# Out:
#        Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li     Al  \
# 0    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 1    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 2    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 3    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 4    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# ..    ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...    ...
# 190  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 191  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 192  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 193  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 194  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
#
#       U    I  Q (kJ/cm)  Speed (mm/min)   Strain
# 0    25  200       30.0             100  0.14200
# 1    25  200       30.0             100  0.24500
# 2    25  200       30.0             100  0.49500
# 3    25  200       30.0             100  1.00000
# 4    25  200       30.0             100  1.99700
# ..   ..  ...        ...             ...      ...
# 190  18  230        NaN             100  0.10170
# 191  18  230        NaN             100  0.09969
# 192  18  230        NaN             100  2.31700
# 193  18  230        NaN             100  0.59890
# 194  18  230        NaN             100  0.11540
#
# [195 rows x 18 columns]

# %%
subdata.drop("Q (kJ/cm)", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
subdata.drop("Speed (mm/min)", axis=1, inplace=True)
display(subdata)
# Out:
#        Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li     Al  \
# 0    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 1    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 2    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 3    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 4    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# ..    ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...    ...
# 190  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 191  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 192  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 193  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 194  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
#
#       Strain
# 0    0.14200
# 1    0.24500
# 2    0.49500
# 3    1.00000
# 4    1.99700
# ..       ...
# 190  0.10170
# 191  0.09969
# 192  2.31700
# 193  0.59890
# 194  0.11540
#
# [195 rows x 14 columns]

# %%
X = subdata.iloc[:, 0:12].values
y = subdata.iloc[:, 13].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8)

# %%
stnrf_al = RandomForestRegressor(n_estimators = 40, n_jobs=-1, oob_score = True)
stnrf_al.fit(X_train, y_train)
print_score(stnrf_al)
# Out:
# [0.7253858603022099, 0.9189164319232057, 0.09768690829959692, -0.26355916673988067, -0.28825900648550706]

# %%
from matplotlib import pyplot as plt

yhat = stnrf_al.predict(X_test)
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter(y_test, yhat)
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [.1, 3]
yy = [.1, 3]
plt.plot( xx, yy, color="red")
plt.tight_layout()

# %%
r2_score(y_test,yhat)
# Out:
# -0.26355916673988067

# %%
rmse(yhat,y_test)
# Out:
# 0.9189164319232057

# %%
subdata = data[np.isfinite(data['Strain'])]
display(subdata)
# Out:
#        Name    Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li  \
# 0    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 1    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 2    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 3    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# 4    5083_3  0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...
# 190       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 191       D  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0
# 192       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 193       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
# 194       E  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0
#
#         Al   U    I  Q (kJ/cm)  Speed (mm/min)   Strain    MCL
# 0    94.44  25  200       30.0             100  0.14200  2.738
# 1    94.44  25  200       30.0             100  0.24500  3.600
# 2    94.44  25  200       30.0             100  0.49500  4.815
# 3    94.44  25  200       30.0             100  1.00000  5.338
# 4    94.44  25  200       30.0             100  1.99700  5.492
# ..     ...  ..  ...        ...             ...      ...    ...
# 190  96.70  18  230        NaN             100  0.10170  3.205
# 191  96.70  18  230        NaN             100  0.09969  2.369
# 192  94.67  18  230        NaN             100  2.31700  4.635
# 193  94.67  18  230        NaN             100  0.59890  4.550
# 194  94.67  18  230        NaN             100  0.11540  4.062
#
# [195 rows x 20 columns]

# %%
subdata = subdata.loc[:, 'Si':'Strain']
display(subdata)
# Out:
#        Si    Fe    Cu    Mn    Mg    Cr    Zn    Ti   Zr  V    B   Li     Al  \
# 0    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 1    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 2    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 3    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# 4    0.14  0.20  0.02  0.67  4.39  0.12  0.00  0.02  0.0  0  0.0  0.0  94.44
# ..    ...   ...   ...   ...   ...   ...   ...   ...  ... ..  ...  ...    ...
# 190  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 191  0.07  0.19  3.00  0.01  0.02  0.00  0.01  0.00  0.0  0  0.0  0.0  96.70
# 192  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 193  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
# 194  0.07  0.22  4.96  0.01  0.04  0.00  0.03  0.00  0.0  0  0.0  0.0  94.67
#
#       U    I  Q (kJ/cm)  Speed (mm/min)   Strain
# 0    25  200       30.0             100  0.14200
# 1    25  200       30.0             100  0.24500
# 2    25  200       30.0             100  0.49500
# 3    25  200       30.0             100  1.00000
# 4    25  200       30.0             100  1.99700
# ..   ..  ...        ...             ...      ...
# 190  18  230        NaN             100  0.10170
# 191  18  230        NaN             100  0.09969
# 192  18  230        NaN             100  2.31700
# 193  18  230        NaN             100  0.59890
# 194  18  230        NaN             100  0.11540
#
# [195 rows x 18 columns]

# %%
subdata.drop("Q (kJ/cm)", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
#subdata.drop("Strain", axis=1, inplace=True)
subdata.drop("Speed (mm/min)", axis=1, inplace=True)
subdata.drop("Si", axis=1, inplace=True)
subdata.drop("Mg", axis=1, inplace=True)
subdata.drop("Fe", axis=1, inplace=True)
subdata.drop("Mn", axis=1, inplace=True)
subdata.drop("Cr", axis=1, inplace=True)
#subdata.drop("Zn", axis=1, inplace=True)
#subdata.drop("Ti", axis=1, inplace=True)
#subdata.drop("Zr", axis=1, inplace=True)
subdata.drop("V", axis=1, inplace=True)
#subdata.drop("B", axis=1, inplace=True)
subdata.drop("Li", axis=1, inplace=True)
subdata.drop("Al", axis=1, inplace=True)
subdata.drop("Cu", axis=1, inplace=True)

display(subdata)
# Out:
#        Zn    Ti   Zr    B   Strain
# 0    0.00  0.02  0.0  0.0  0.14200
# 1    0.00  0.02  0.0  0.0  0.24500
# 2    0.00  0.02  0.0  0.0  0.49500
# 3    0.00  0.02  0.0  0.0  1.00000
# 4    0.00  0.02  0.0  0.0  1.99700
# ..    ...   ...  ...  ...      ...
# 190  0.01  0.00  0.0  0.0  0.10170
# 191  0.01  0.00  0.0  0.0  0.09969
# 192  0.03  0.00  0.0  0.0  2.31700
# 193  0.03  0.00  0.0  0.0  0.59890
# 194  0.03  0.00  0.0  0.0  0.11540
#
# [195 rows x 5 columns]

# %%
X = subdata.iloc[:, 0:3].values
y = subdata.iloc[:, 4].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
lasso_rf = RandomForestRegressor(n_estimators = 40, n_jobs=-1, oob_score = True)
lasso_rf.fit(X_train, y_train)
print_score(lasso_rf)
# Out:
# [0.7318649254604649, 0.9140076886349078, 0.044048221216165695, -0.143789687110236, -0.1909516822735564]

# %%
from matplotlib import pyplot as plt

yhat = lasso_rf.predict(X_test)
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter(y_test, yhat)
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [.1, 4]
yy = [.1, 4]
plt.plot( xx, yy, color="red")
plt.tight_layout()

# %%
r2_score(y_test,yhat)
# Out:
# -0.143789687110236

# %% [markdown]
# #Steel Data: Total Crack Length Random Forest Regression

# %%
#RF for Steel dataset
data = pd.read_csv("/content/drive/MyDrive/steel_data.csv", sep = ",")
print(data.head())
display(data)
# Out:
#    No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...    Al  \
# 0    1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...  0.02
# 1    2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...  0.02
# 2    3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...  0.02
# 3    4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...  0.02
# 4    5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...  0.02
#
#     Ti    V    B    Th    I     U    Ve  Strain  TCL
# 0  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.5
# 1  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.1
# 2  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.9
# 3  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.7
# 4  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.5
#
# [5 rows x 23 columns]
#      No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...  \
# 0      1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...
# 1      2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...
# 2      3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...
# 3      4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...
# 4      5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...
# ..   ...    ...   ...   ...    ...    ...    ...    ...   ...    ...  ...
# 482  483  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  ...
# 483  484  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  ...
# 484  485  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  ...
# 485  486  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  ...
# 486  487  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 23 columns]

# %%
subdata = data[np.isfinite(data['TCL'])]
display(subdata)
# Out:
#      No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...  \
# 0      1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...
# 1      2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...
# 2      3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...
# 3      4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...
# 4      5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...
# ..   ...    ...   ...   ...    ...    ...    ...    ...   ...    ...  ...
# 482  483  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  ...
# 483  484  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  ...
# 484  485  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  ...
# 485  486  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  ...
# 486  487  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 23 columns]

# %%
subdata = subdata.loc[:, 'C':'TCL']
display(subdata)
# Out:
#          C    Si    Mn      P      S     Cr     Ni    Mo      N    Nb  ...  \
# 0    0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  0.00  ...
# 1    0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  0.00  ...
# 2    0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  0.00  ...
# 3    0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  0.00  ...
# 4    0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  0.00  ...
# ..     ...   ...   ...    ...    ...    ...    ...   ...    ...   ...  ...
# 482  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  0.28  ...
# 483  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  0.28  ...
# 484  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  0.30  ...
# 485  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  0.00  ...
# 486  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  0.00  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 22 columns]

# %%
subdata.drop("Ve", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
subdata.drop("Strain", axis=1, inplace=True)
subdata.drop("Th", axis=1, inplace=True)
display(subdata)
# Out:
#          C    Si    Mn      P      S     Cr     Ni    Mo      N    Nb    Co  \
# 0    0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  0.00  0.00
# 1    0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  0.00  0.00
# 2    0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  0.00  0.00
# 3    0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  0.00  0.00
# 4    0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  0.00  0.15
# ..     ...   ...   ...    ...    ...    ...    ...   ...    ...   ...   ...
# 482  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  0.28  0.00
# 483  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  0.28  0.00
# 484  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  0.30  0.00
# 485  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  0.00  0.00
# 486  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  0.00  0.00
#
#       Cu    Al   Ti    V    B   TCL
# 0    0.0  0.02  0.0  0.0  0.0  1.50
# 1    0.0  0.02  0.0  0.0  0.0  1.10
# 2    0.0  0.02  0.0  0.0  0.0  0.90
# 3    0.0  0.02  0.0  0.0  0.0  3.70
# 4    0.0  0.02  0.0  0.0  0.0  1.50
# ..   ...   ...  ...  ...  ...   ...
# 482  0.0  0.02  0.0  0.0  0.0  0.18
# 483  0.0  0.02  0.0  0.0  0.0  0.00
# 484  0.0  0.02  0.0  0.0  0.0  0.24
# 485  0.0  0.02  0.0  0.0  0.0  0.00
# 486  0.0  0.02  0.0  0.0  0.0  1.47
#
# [487 rows x 17 columns]

# %%
X = subdata.iloc[:, 0:15].values
y = subdata.iloc[:, 16].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8)

# %%
rf_stl = RandomForestRegressor(n_estimators = 40, n_jobs=-1, oob_score = True)
rf_stl.fit(X_train, y_train)
print_score(rf_stl)
# Out:
# [2.7545136414882303, 3.3509430094693875, 0.5790113790168057, 0.27315395471588066, 0.2523436561224224]

# %%
from matplotlib import pyplot as plt

yhat = rf_stl.predict(X_test)
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter(y_test, yhat)
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [.1, 15]
yy = [.1, 15]
plt.plot( xx, yy, color="red")
plt.tight_layout()

# %%
from sklearn.metrics import r2_score
r2_score(y_test,yhat)
# Out:
# 0.27315395471588066

# %%
rmse(yhat,y_test)
# Out:
# 3.3509430094693875

# %% [markdown]
# #Steel Data: Strain Random Forest Regression

# %%
#Steel Data: Strain Random Forest Regression
data = pd.read_csv("/content/drive/MyDrive/steel_data.csv", sep = ",")
print(data.head())
display(data)
# Out:
#    No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...    Al  \
# 0    1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...  0.02
# 1    2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...  0.02
# 2    3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...  0.02
# 3    4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...  0.02
# 4    5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...  0.02
#
#     Ti    V    B    Th    I     U    Ve  Strain  TCL
# 0  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.5
# 1  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.1
# 2  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.9
# 3  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.7
# 4  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.5
#
# [5 rows x 23 columns]
#      No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...  \
# 0      1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...
# 1      2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...
# 2      3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...
# 3      4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...
# 4      5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...
# ..   ...    ...   ...   ...    ...    ...    ...    ...   ...    ...  ...
# 482  483  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  ...
# 483  484  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  ...
# 484  485  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  ...
# 485  486  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  ...
# 486  487  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 23 columns]

# %%
subdata = data[np.isfinite(data['Strain'])]
display(subdata)
# Out:
#      No.      C    Si    Mn      P      S     Cr     Ni    Mo      N  ...  \
# 0      1  0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  ...
# 1      2  0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  ...
# 2      3  0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  ...
# 3      4  0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  ...
# 4      5  0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  ...
# ..   ...    ...   ...   ...    ...    ...    ...    ...   ...    ...  ...
# 482  483  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  ...
# 483  484  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  ...
# 484  485  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  ...
# 485  486  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  ...
# 486  487  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  ...
#
#        Al   Ti    V    B    Th    I     U    Ve  Strain   TCL
# 0    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# 1    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.10
# 2    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  0.90
# 3    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  3.70
# 4    0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0  1.50
# ..    ...  ...  ...  ...   ...  ...   ...   ...     ...   ...
# 482  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.18
# 483  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 484  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.24
# 485  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  0.00
# 486  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2  1.47
#
# [487 rows x 23 columns]

# %%
subdata = subdata.loc[:, 'C':'Strain']
display(subdata)
# Out:
#          C    Si    Mn      P      S     Cr     Ni    Mo      N    Nb  ...  \
# 0    0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  0.00  ...
# 1    0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  0.00  ...
# 2    0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  0.00  ...
# 3    0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  0.00  ...
# 4    0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  0.00  ...
# ..     ...   ...   ...    ...    ...    ...    ...   ...    ...   ...  ...
# 482  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  0.28  ...
# 483  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  0.28  ...
# 484  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  0.30  ...
# 485  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  0.00  ...
# 486  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  0.00  ...
#
#       Cu    Al   Ti    V    B    Th    I     U    Ve  Strain
# 0    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# 1    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# 2    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# 3    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# 4    0.0  0.02  0.0  0.0  0.0  3.18  100  12.0  4.23     4.0
# ..   ...   ...  ...  ...  ...   ...  ...   ...   ...     ...
# 482  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
# 483  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
# 484  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
# 485  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
# 486  0.0  0.02  0.0  0.0  0.0  5.00   70  16.0  1.25     1.2
#
# [487 rows x 21 columns]

# %%
subdata.drop("Ve", axis=1, inplace=True)
subdata.drop("I", axis=1, inplace=True)
subdata.drop("U", axis=1, inplace=True)
subdata.drop("Th", axis=1, inplace=True)
display(subdata)
# Out:
#          C    Si    Mn      P      S     Cr     Ni    Mo      N    Nb    Co  \
# 0    0.010  0.48  1.61  0.024  0.019  17.33  10.62  2.09  0.060  0.00  0.00
# 1    0.011  0.58  1.06  0.032  0.013  16.95  10.50  2.15  0.078  0.00  0.00
# 2    0.010  0.46  1.09  0.021  0.001  17.40  11.50  2.88  0.105  0.00  0.00
# 3    0.010  0.51  1.60  0.021  0.001  17.55  12.95  2.76  0.113  0.00  0.00
# 4    0.012  0.46  1.54  0.027  0.023  16.28  10.15  2.06  0.098  0.00  0.15
# ..     ...   ...   ...    ...    ...    ...    ...   ...    ...   ...   ...
# 482  0.016  0.34  1.76  0.024  0.008  17.90   9.90  0.00  0.045  0.28  0.00
# 483  0.014  0.35  1.67  0.027  0.007  17.70   9.70  0.00  0.047  0.28  0.00
# 484  0.014  0.33  1.73  0.026  0.007  17.90   9.50  0.00  0.046  0.30  0.00
# 485  0.050  0.75  0.94  0.026  0.007  18.30   9.40  0.00  0.016  0.00  0.00
# 486  0.070  0.66  1.01  0.020  0.006  16.70  12.40  2.38  0.020  0.00  0.00
#
#       Cu    Al   Ti    V    B  Strain
# 0    0.0  0.02  0.0  0.0  0.0     4.0
# 1    0.0  0.02  0.0  0.0  0.0     4.0
# 2    0.0  0.02  0.0  0.0  0.0     4.0
# 3    0.0  0.02  0.0  0.0  0.0     4.0
# 4    0.0  0.02  0.0  0.0  0.0     4.0
# ..   ...   ...  ...  ...  ...     ...
# 482  0.0  0.02  0.0  0.0  0.0     1.2
# 483  0.0  0.02  0.0  0.0  0.0     1.2
# 484  0.0  0.02  0.0  0.0  0.0     1.2
# 485  0.0  0.02  0.0  0.0  0.0     1.2
# 486  0.0  0.02  0.0  0.0  0.0     1.2
#
# [487 rows x 17 columns]

# %%
X = subdata.iloc[:, 0:15].values
y = subdata.iloc[:, 16].values
X, y = X.astype('float'), y.astype('float')
n_features = X.shape[1]

# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=9)

# %%
rf_stl2 = RandomForestRegressor(n_estimators = 40, n_jobs=-1, oob_score = True)
rf_stl2.fit(X_train, y_train)
print_score(rf_stl2)
# Out:
# [1.0202317534086354, 1.3102352699098692, 0.4739435576712382, 0.11844778483017504, -0.0347013447065907]

# %%
from matplotlib import pyplot as plt

yhat = rf_stl2.predict(X_test)
plt.subplots_adjust( left = 0.16, bottom = 0.15 , top = 0.85 )
plt.scatter(y_test, yhat)
plt.xlabel("$y_{test}$",fontsize = 20, weight = 'bold')
plt.ylabel("$\hat{y}$",fontsize = 20, weight = 'bold')
xx = [.1, 6]
yy = [.1, 6]
plt.plot( xx, yy, color="red")
plt.tight_layout()

# %%
#R^2 value
from sklearn.metrics import r2_score
r2_score(y_test,yhat)
# Out:
# 0.11844778483017504

# %%
#RMSE Value
rmse(yhat,y_test)
# Out:
# 1.3102352699098692
